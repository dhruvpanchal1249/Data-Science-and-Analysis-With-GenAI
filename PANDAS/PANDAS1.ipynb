# %%
import numpy as np
import pandas as pd

# %%
x=([1,2,3],[20,21,22])
arr=np.array(x)
arr
# Out:
# array([[ 1,  2,  3],
#        [20, 21, 22]])

# %%
y=([1,5,3],[27,20,22])
arr2=np.array(y)
arr2
# Out:
# array([[ 1,  5,  3],
#        [27, 20, 22]])

# %%
arr*arr2
# Out:
# array([[  1,  10,   9],
#        [540, 420, 484]])

# %%
arr+arr2
# Out:
# array([[ 2,  7,  6],
#        [47, 41, 44]])

# %%
print("hello world this is dhruv panchal and i live in ahmedabad ")
# Out:
# hello world
